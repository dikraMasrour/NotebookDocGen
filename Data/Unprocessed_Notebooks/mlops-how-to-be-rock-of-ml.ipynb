# %% [markdown]
# # <span style="color:#011936;">**MLOps and production approach to ML research**<span>
# ### <span style="color:#011936;">**Advanced approaches and tools for developing and implementing ML solutions in production.**<span>
#
# <span style="color:#465362;">You will learn how to organize the workflow of an ml development team from scratch. You will go through all the steps of creating an ML service from organizing a repository to setting up CI / CD and integrating an ML model into operation. Master the concept of reproducible and scalable research. Get acquainted with popular team development tools: GitLab, SnakeMake, MLFlow, DVC, learn how to unify the release cycle of machine learning models and software products created on their basis, and be able to automate testing of produced artifacts.<span>
#
# ## <span style="color:#FF6542;">**I suggest to сheckout other works**<span>
# >[**Spaceship Titanic**](https://www.kaggle.com/code/kartushovdanil/deep-eda-to-infinity-and-beyond)
# [**TPS FEB 22**](https://www.kaggle.com/code/kartushovdanil/tps-feb-22-advanced-eda)
# [**TPS JAN 21 PART 2**](https://www.kaggle.com/code/kartushovdanil/overfit-me-catboost-lgbm)
# [**TPS JAN 21 PART 1**](https://www.kaggle.com/code/kartushovdanil/tps-jan-22-eda-atboost-prophet)
# [**TPS NOV 21**](https://www.kaggle.com/code/kartushovdanil/tps-nov21-4-begginers-rus-links)

# %% [markdown]
# # <span style="color:#011936;">**The concept of reproducible and scalable research**<span>
# <a id="1"></a>
#
# **I want to start with explain that mlops is part of devops. The most part of your time you will write code in IDE and .py, after this guide, i hope you get knowledge and skills how to automate your code and be sure that everythink working okey. That`s also useful for kagglers, if you gonna get next level and tired of jupyter.**
#
# So, the first rule of MLOPS or any other research is 3R (non official called,  just called by me)
#
# >Repeatability (same team, same experimental setup): The measurement can be obtained with stated precision by the same team using the same measurement procedure, the same measuring system, under the same operating conditions, in the same location on multiple trials.
#
# >Reproducibility (different team, different experimental setup): The measurement can be obtained with stated precision by a different team, a different measuring system, in a different location on multiple trials.
#
# >Replicability (different team, same experimental setup): The measurement can be obtained with stated precision by a different team using the same measurement procedure, the same measuring system, under the same operating conditions, in the same or a different location on multiple trials.
#
# So in other words, your code or project, needs to be enough to use other people and suitable for different OS, python or packages versions.
#
# A little later we will move on to an overview of the tools that will help us. But let's think about how we can do it manually?
#
# > Write various installation instructions, according to the requirements. What resources did you have for this.

# %% [markdown]
# # <span style="color:#011936;">**Tools overview**<span>
#
#
# ### <span style="color:#011936;">**Pyenv + Poetry**<span>
# The first tools, to make local python and enviroments.
# Poetry is better then virtualenv and conda, there more features of managing enviroments.
#
# ### <span style="color:#011936;">**CookieCutter**<span>
# The second about project enviroment, devops also about how to manage files,therefore you can download their templates.
#
# ### <span style="color:#011936;">**Docker + K8S**<span>
# This most valuable tools, becouse docker is awesome. You dont need care about OS or other problems with repeatability, docker is all you need.
# K8S is optional, but if you have a large project with CI/CD, then it will distribute the load on the server
#
# ### <span style="color:#011936;">**PyCharm**<span>
# I prefer this IDE, for me it is one of the most convenient and productive.
#
# ### <span style="color:#011936;">**CLI**<span>
# The CLI is a handy thing, because in the future, most likely you will have to run your code from the console or some tools will have requirements for this. Therefore, I suggest you use **click** for this. And besides, it's convenient, you just need to pass two parameters and you will start a mini pipeline.
#
# ### <span style="color:#011936;">**Weights & Biases**<span>
# If you want to remotely save your learning or get results and compare them later, while not storing them locally, then this is probably the most convenient tool for this.
#
# ### <span style="color:#011936;">**DVC**<span>
# Data version control, the strongest mlops tool, but based on git.
#
# ### <span style="color:#011936;">**GitLab CI**<span>
# it will not only store your project, but also CI as a gift
#
# ### <span style="color:#011936;">**PyTests**<span>
#
#
#
# ### <span style="color:#011936;">**FastAPI**<span>

# %% [markdown]
# # <span style="color:#011936;">**Settings projects**<span>
#
# At first you need to install cookiecutter project, docker, enviroment and local python.
# [Cookiecutter Instructions](https://drivendata.github.io/cookiecutter-data-science/)
# [Poetry](https://python-poetry.org/docs/)
# [Docker](https://docker-curriculum.com)
#
# Afther this i suggest to read this: [mlops](https://ml-ops.org) and [github, more mlops tools](https://github.com/chekh/awesome-mlops)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('l-jwZPOCChg', width=800, height=300)

# %%
YouTubeVideo('3gf60ncxe28', width=800, height=300)

# %%
YouTubeVideo('dzSp3Zf897g', width=800, height=300)
