# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = "../data/cleaned_ntb_only_en_scd.pkl"

# %%
df = pd.read_pickle(DATA_PATH)
df
# Out:
#        cell-type                                             source  \
# 0           code  import pandas as pd import numpy as np import ...
# 1       markdown  try to overfit more pls upvote if you fork lik...
# 2       markdown                                         sub1 0 869
# 3       markdown  credit very simple code with score 0 886 by ay...
# 4           code  import pandas as pd import numpy as np from sk...
# ...          ...                                                ...
# 344966      code   POI_data = gpd.read_file("../input/geospatial...
# 344967  markdown  next we create a map from all four geodatafram...
# 344968      code   ax = counties.plot(figsize=(10,10), color='no...
# 344969  markdown  it looks like the northeastern part of the sta...
# 344970  markdown  have questions or comments visit the course di...
#
#                                                title                     tag
# 0       0-9-try-better-parameters-better-score.ipynb              regression
# 1       0-9-try-better-parameters-better-score.ipynb              regression
# 2       0-9-try-better-parameters-better-score.ipynb              regression
# 3       0-9-try-better-parameters-better-score.ipynb              regression
# 4       0-9-try-better-parameters-better-score.ipynb              regression
# ...                                              ...                     ...
# 344966                          your-first-map.ipynb  reinforcement learning
# 344967                          your-first-map.ipynb  reinforcement learning
# 344968                          your-first-map.ipynb  reinforcement learning
# 344969                          your-first-map.ipynb  reinforcement learning
# 344970                          your-first-map.ipynb  reinforcement learning
#
# [332605 rows x 4 columns]

# %%
for i in df.columns:
    df[i].fillna(' ', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332605 entries, 0 to 344970
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   cell-type  332605 non-null  object
#  1   source     332605 non-null  object
#  2   title      332605 non-null  object
#  3   tag        332605 non-null  object
# dtypes: object(4)
# memory usage: 12.7+ MB

# %%
df_tansf = pd.DataFrame(columns=['md_pair','cd_pair','title','tag'])
df_tansf
# Out:
# Empty DataFrame
# Columns: [md_pair, cd_pair, title, tag]
# Index: []

# %%
def transf_only_cd_ntb(old_data,new_data,counter):
    for i in old_data.index :
        if (len(str(old_data.loc[i]['source']).split())) < 256 and (len(str(old_data.loc[i]['source']).split())) > 3:
            new_data.loc[len(new_data)] = [" ",str(old_data.loc[i]['source']),str(old_data.loc[i]['title']),str(old_data.loc[i]['tag'])]
        else:
            counter += 1
    
    return counter

# %%
def transf_only_md_ntb(old_data,new_data,counter):
    for i in old_data.index :
        if (len(str(old_data.loc[i]['source']).split())) < 256 and (len(str(old_data.loc[i]['source']).split())) > 3:
            new_data.loc[len(new_data)] = [str(old_data.loc[i]['source'])," ",str(old_data.loc[i]['title']),str(old_data.loc[i]['tag'])]
        else:
            counter += 1
    
    return counter

# %%
def construct_pairs(old_data,new_data,counter,limit):
    rgp_md = ''
    index = 0 

    
    try:
        while(str(old_data.iloc[index]['cell-type']) == "markdown") and counter < limit:
                rgp_md += str(old_data.iloc[index]['source']) + " "
                index +=1 
                
    except Exception as e:
        print('Here 1 :',e,counter+index)
    
    try:
        while(str(old_data.iloc[index]['cell-type']) == "code") and counter < limit:
                new_data.loc[len(new_data)] = [rgp_md,str(old_data.iloc[index]['source']),str(old_data.iloc[index]['title']),str(old_data.iloc[index]['tag'])]
                index +=1
    except Exception as e:
        print('Here 2 :',e,counter+index)

    counter += index

    if counter < limit :
                        print(counter)
                        construct_pairs(old_data.loc[counter:],new_data,counter,limit)

# %%
def transf_ntb(old_data,new_data):
    if old_data.iloc[0]['cell-type'] == "code":
        new_data.loc[len(new_data)] = [" ",str(old_data.loc[0]['source']),str(old_data.loc[0]['title']),str(old_data.loc[0]['tag'])]
        transf_ntb(old_data[1:],new_data)
    else :
        old_data = old_data.reset_index(drop=True)
        construct_pairs(old_data,new_data,0,len(old_data))

# %%
"""
List_1 = []
List_2 = []
counter_1 = 0
counter_2 = 0
full_text_md = ''
full_text_cd = ''
groups = df.groupby('title')
List_ntb = np.unique(df['title'].tolist()).tolist()
for ntb in List_ntb :
    data_ntb = df[df['title'] == ntb] 
    for i in data_ntb.index:
            if data_ntb.loc[i]['cell-type'] == "markdown":
                full_text_md += str(data_ntb.loc[i]['source'])
            else :
                full_text_cd += str(data_ntb.loc[i]['source'])
    
    if full_text_md == '' :
        full_text_md = ''
        full_text_cd = ''
        counter_1 += transf_only_cd_ntb(data_ntb,df_tansf,counter_1)
        List_1 .append(ntb)

    elif full_text_cd == '':
        full_text_md = ''
        full_text_cd = ''
        counter_2 += transf_only_md_ntb(data_ntb,df_tansf,counter_2)
        List_2 .append(ntb)

    else :
        full_text_md = full_text_cd = ''

"""
# Out:
# '\nList_1 = []\nList_2 = []\ncounter_1 = 0\ncounter_2 = 0\nfull_text_md = \'\'\nfull_text_cd = \'\'\ngroups = df.groupby(\'title\')\nList_ntb = np.unique(df[\'title\'].tolist()).tolist()\nfor ntb in List_ntb :\n    data_ntb = df[df[\'title\'] == ntb] \n    for i in data_ntb.index:\n            if data_ntb.loc[i][\'cell-type\'] == "markdown":\n                full_text_md += str(data_ntb.loc[i][\'source\'])\n            else :\n                full_text_cd += str(data_ntb.loc[i][\'source\'])\n    \n    if full_text_md == \'\' :\n        full_text_md = \'\'\n        full_text_cd = \'\'\n        counter_1 += transf_only_cd_ntb(data_ntb,df_tansf,counter_1)\n        List_1 .append(ntb)\n\n    elif full_text_cd == \'\':\n        full_text_md = \'\'\n        full_text_cd = \'\'\n        counter_2 += transf_only_md_ntb(data_ntb,df_tansf,counter_2)\n        List_2 .append(ntb)\n\n    else :\n        full_text_md = full_text_cd = \'\'\n\n'

# %%
#List_1

# %%
#List_2

# %% [markdown]
# windows-yolov5l.ipynb MUST BE DELETED chineesee ntb

# %%
df_tansf = pd.DataFrame(columns=['md_pair','cd_pair','title','tag'])
df_tansf

transf_ntb(df[:20],df_tansf)
# Out:
# 4
# 7
# 10
# 12
# 17
# Here 1 : single positional indexer is out-of-bounds 19
# Here 2 : single positional indexer is out-of-bounds 19

# %%
df[:20]
# Out:
#    cell-type                                             source  \
# 0       code  import pandas as pd import numpy as np import ...
# 1   markdown  try to overfit more pls upvote if you fork lik...
# 2   markdown                                         sub1 0 869
# 3   markdown  credit very simple code with score 0 886 by ay...
# 4       code  import pandas as pd import numpy as np from sk...
# 5   markdown                                         sub2 0 860
# 6   markdown  credit tokenizer training tfidf ridge lb 0 860...
# 7       code  import numpy as np import pandas as pd import ...
# 8   markdown                                         sub3 0 858
# 9   markdown  credit rapids tfidf linear model ensemble by z...
# 10      code  import pandas as pd import numpy as np from tq...
# 11  markdown                                         sub4:0 873
# 12      code  from sklearn.linear_model import LinearRegress...
# 13  markdown  you can try to modify the parameters to get a ...
# 14      code  data = pd.read_csv("./submission1.csv",index_c...
# 15      code
# 16      code   for f in ['score1','score2','score3']:     fo...
# 17      code   data["score"] = .66*data["score1"] + .66*data...
# 18  markdown                              for even more overfit
# 19  markdown  credit scaling for jigsaw ensemble by chryzal ...
#
#                                            title         tag
# 0   0-9-try-better-parameters-better-score.ipynb  regression
# 1   0-9-try-better-parameters-better-score.ipynb  regression
# 2   0-9-try-better-parameters-better-score.ipynb  regression
# 3   0-9-try-better-parameters-better-score.ipynb  regression
# 4   0-9-try-better-parameters-better-score.ipynb  regression
# 5   0-9-try-better-parameters-better-score.ipynb  regression
# 6   0-9-try-better-parameters-better-score.ipynb  regression
# 7   0-9-try-better-parameters-better-score.ipynb  regression
# 8   0-9-try-better-parameters-better-score.ipynb  regression
# 9   0-9-try-better-parameters-better-score.ipynb  regression
# 10  0-9-try-better-parameters-better-score.ipynb  regression
# 11  0-9-try-better-parameters-better-score.ipynb  regression
# 12  0-9-try-better-parameters-better-score.ipynb  regression
# 13  0-9-try-better-parameters-better-score.ipynb  regression
# 14  0-9-try-better-parameters-better-score.ipynb  regression
# 15  0-9-try-better-parameters-better-score.ipynb  regression
# 16  0-9-try-better-parameters-better-score.ipynb  regression
# 17  0-9-try-better-parameters-better-score.ipynb  regression
# 18  0-9-try-better-parameters-better-score.ipynb  regression
# 19  0-9-try-better-parameters-better-score.ipynb  regression

# %%
df_tansf
# Out:
#                                              md_pair  \
# 0
# 1  try to overfit more pls upvote if you fork lik...
# 2  sub2 0 860 credit tokenizer training tfidf rid...
# 3  sub3 0 858 credit rapids tfidf linear model en...
# 4                                        sub4:0 873
# 5  you can try to modify the parameters to get a ...
# 6  you can try to modify the parameters to get a ...
# 7  you can try to modify the parameters to get a ...
# 8  you can try to modify the parameters to get a ...
#
#                                              cd_pair  \
# 0  import pandas as pd import numpy as np import ...
# 1  import pandas as pd import numpy as np from sk...
# 2  import numpy as np import pandas as pd import ...
# 3  import pandas as pd import numpy as np from tq...
# 4  from sklearn.linear_model import LinearRegress...
# 5  data = pd.read_csv("./submission1.csv",index_c...
# 6
# 7   for f in ['score1','score2','score3']:     fo...
# 8   data["score"] = .66*data["score1"] + .66*data...
#
#                                           title         tag
# 0  0-9-try-better-parameters-better-score.ipynb  regression
# 1  0-9-try-better-parameters-better-score.ipynb  regression
# 2  0-9-try-better-parameters-better-score.ipynb  regression
# 3  0-9-try-better-parameters-better-score.ipynb  regression
# 4  0-9-try-better-parameters-better-score.ipynb  regression
# 5  0-9-try-better-parameters-better-score.ipynb  regression
# 6  0-9-try-better-parameters-better-score.ipynb  regression
# 7  0-9-try-better-parameters-better-score.ipynb  regression
# 8  0-9-try-better-parameters-better-score.ipynb  regression

# %%
import re
import numpy  as np
data = df[df['cell-type']=='code']
l=[]
for i in data.index:
        if data.loc[i]['source'].startswith("['") and data.loc[i]['source'].endswith("']"):
            l.append(data.loc[i]['title'])
np.unique(l)
# Out:
# array(['stocks-reinforcement-learning-ensemble.ipynb',
#        'world-happiness-and-65-world-indexes.ipynb',
#        'xlm-roberta-base.ipynb', 'yolov5-vinbigdata.ipynb'], dtype='<U44')
