# %% [markdown]
# ## Kaggle Python public API for data collection : Notebook Classification TASK

# %%
DATA_PATH_KEYWORDS = '../data/search_keywords.csv'
DATA_PATH_NOTEBOOKS = '../data/'

# %% [markdown]
# Importing librairies

# %%
import kaggle
from kaggle.api.kaggle_api_extended import KaggleApi
import pandas as pd

# %%
api = KaggleApi()
api.authenticate()

# %% [markdown]
# Read the file containing the search keywords used to retrieve notebooks

# %%
keywords_df = pd.DataFrame(columns=['Category', 'Subcategory'])
keywords_df = pd.read_csv(DATA_PATH_KEYWORDS, sep=';') 
keywords_df
# Out:
#                                           subcategory                category
# 0                                   linear regression              regression
# 1                                    lasso regression              regression
# 2                                    ridge regression              regression
# 3                    support vector machine regressor              regression
# 4                                                 svr              regression
# 5                                 logistic regression          classification
# 6                   support vector machine classifier          classification
# 7                                                 svc          classification
# 8                                         naive bayes          classification
# 9                                                 knn          classification
# 10                           decision tree classifier          classification
# 11                                k nearest neighbors          classification
# 12                                            k means              clustering
# 13                                spectral clustering              clustering
# 14                                                hca              clustering
# 15                      hierarchical cluster analysis              clustering
# 16                                          chameleon              clustering
# 17                                                 ap              clustering
# 18                               affinity propagation              clustering
# 19                                self organising map              clustering
# 20  Density Based Spatial Clustering of Applicatio...              clustering
# 21                                         clustering              clustering
# 22                                             DBSCAN              clustering
# 23                              semantic segmentation         computer vision
# 24                              instance segmentation         computer vision
# 25                          region based segmentation         computer vision
# 26                        edge detection segmentation         computer vision
# 27                                   object detection         computer vision
# 28                                  image recognition         computer vision
# 29                                 facial recognition         computer vision
# 30                               image classification         computer vision
# 31                                   feature matching         computer vision
# 32                                    computer vision         computer vision
# 33                                machine translation                     nlp
# 34                                 sentiment analysis                     nlp
# 35                                 question answering                     nlp
# 36                              information retrieval                     nlp
# 37                                 speech recognition                     nlp
# 38                                 text summarisation                     nlp
# 39                                    text generation                     nlp
# 40                                                nlp                     nlp
# 41                           named entity recognition                     nlp
# 42                                         q learning  reinforcement learning
# 43                                    markov decision  reinforcement learning
# 44                                multi armed bandits  reinforcement learning
# 45                             reinforcement learning  reinforcement learning
# 46                                         geospatial     geospatial analysis

# %%
def search(sub,data):
    for i in data.index:
        if data.loc[i]['subcategory']==sub:
            return data.loc[i]['category']

# %% [markdown]
# # Collecting notebooks by subcategory

# %%
for keyword in keywords_df['subcategory']:
    for i in range(1,16):
        try :
                kernels = api.kernels_list(search=keyword,page=i)
                for kernel in kernels:
                        api.kernels_pull(kernel.ref,path=DATA_PATH_NOTEBOOKS+search(keyword,keywords_df))
        except Exception as e:
            print('Kaggle API exception : Notebook not found')
# Out:
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
# Kaggle API exception : Notebook not found
